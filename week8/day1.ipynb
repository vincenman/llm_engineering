# %% [markdown]
# # Welcome to a very busy Week 8 folder
#
# ## We have lots to do this week!
#
# We'll move at a faster pace than usual, particularly as you're becoming proficient LLM engineers.
#
# # The Price is Right
#
# ## Week 8 Order of Play
#
# Day 1: Modal.com and SpecialistAgent
# Day 2: RAG, FrontierAgent, Ensemble Agent
# Day 3: ScannerAgent, MessengerAgent
# Day 4: AutonomousPlannerAgent and DealAgentFramework
# Day 5: The Price Is Right Finale

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#b22;">Especially important this week: pull the latest</h2>
#             <span style="color:#b22;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             Please see Guide 3 in the Guides folder if you're not sure how to do a <code>git pull</code>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
import os
import locale
import modal
from agents.preprocessor import Preprocessor
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
# To check that your computer can output special characters, make sure this outputs UTF-8 

print(locale.getpreferredencoding())  # Should print 'UTF-8'
# Out:
# cp950

# %%
os.environ["PYTHONIOENCODING"] = "utf-8"

# %% [markdown]
# # Setting up the modal tokens
#
# ## IMPORTANT - please do read and follow these instructions!
#
# First please visit: https://modal.com
#
# And sign up for an account. Then click the Avatar menu on the top right and select "Settings"
#
# Then click "API Tokens" in the left sidebar, then click "New Token".
#
# You will be given something like this to run:
#
# `modal token set --token-id ak-somethinghere --token-secret as-somethinghere`
#
# But because we're using uv, the real thing to run is this:
#
# `uv run modal token set --token-id ak-somethinghere --token-secret as-somethinghere`
#
# ### Troubleshooting
#
# If you have problems, 3 things to try:
#
# 1. Try running `uv run modal token new` before the `uv run modal token set..`
#
# 2. Suggestion from student David S. on Windows:
#
# > In case anyone else using Windows hits this problem: Along with having to run `modal token new` from a command prompt, you have to move the generated token file. It will deploy the token file (.modal.toml) to your Windows profile folder. The virtual environment couldn't see that location (strangely, it couldn't even after I set environment variables for it and rebooted). I moved that token file to the folder I'm operating out of for the lab and it stopped throwing auth errors.
#
# 3. Doing in the manual way:
#
# It might be totally fine to simply add the 2 keys directly to your .env file:
#
# ```
# MODAL_TOKEN_ID=ak-...
# MODAL_TOKEN_SECRET=as-...
# ```
#
# Then rerun `load_dotenv(override=True)` to load these environment variables.

# %%
from hello import app, hello, hello_europe

# %%
with app.run():
    reply=hello.local()
reply
# Out:
# 'Hello from Hong Kong, Hong Kong, HK!!'

# %%
with app.run():
    reply=hello.remote()
reply
# Out:
# 'Hello from Sydney, New South Wales, AU!!'

# %% [markdown]
# ## Added thanks to student Tue H.
#
# If you look in hello.py, I've added a simple function hello_europe
#
# That uses the decorator:
# `@app.function(image=image, region="eu")`
#
# See the result below! More region specific settings are [here](https://modal.com/docs/guide/region-selection)
#
# Note that it does consume marginally more credits to specify a region.

# %%
with app.run():
    reply=hello_europe.remote()
reply
# Out:
# 'Hello from Milan, Lombardy, IT!!'

# %% [markdown]
# # Before we move on -
#
# ## We need to set your HuggingFace Token as a secret in Modal
#
# ## Super important - please read - this confuses a lot of people!
#
# Secrets in Modal are given a **name** that describes the secret.
# Then the secret itself has a KEY and a VALUE.
# We will be setting up a secret with:
#
# Name: huggingface-secret
# Key: HF_TOKEN
# Value: hf_...
#
# ## The bulletproof recipe:
#
# 1. Go to modal.com, sign in and go to your dashboard
# 2. Click on Secrets in the nav bar
# 3. Create new secret, click on Hugging Face, this new secret needs to be called **huggingface-secret** because that's how we refer to it in the code
# 4. Fill in your key as HF_TOKEN and the value as your actual token hf_...
# 5. Click done
#
# ### And now back to business: time to work with Llama

# %%
# This import may give a deprecation warning about adding local Python modules to the Image
# That warning can be safely ignored. You may get the same warning in other places, too..

from llama import app, generate

# %%
with modal.enable_output():
    with app.run():
        result=generate.remote("Never gonna give you up, never gonna")
result

# Or it you object to being rickrolled, try this: "Hey Jude, don't make it"
# Out:
# ✓ Initialized. View run at
# https://modal.com/apps/vincenman/main/ap-Box2DdaDcrEH4RLmnhaYwp
# - Initializing...
# / Creating objects...objects...
# └── - Creating mount
#     d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\llam
# | Creating objects...
# └── | Creating mount
#     d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\llam
# - Creating objects...
# └── - Creating mount
#     d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\llam
# \ Creating objects...
# └── | Creating mount
#     d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\llam
# - Creating objects...
# └── - Creating mount
#     d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\llam
# \ Creating objects...
# ├── 🔨 Created mount
# │   d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\llam
# │   a.py
# / Creating objects...
# ├── 🔨 Created mount
# │   d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\llam
# │   a.py
# └── 🔨 Created function generate.
# ✓ Created objects.
# ├── 🔨 Created mount
# │   d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\llam
# │   a.py
# └── 🔨 Created function generate.
# / Running... View app at
# \ Loading images (1 containers initializing)... View app at
# / Loading images (1 containers initializing)... View app at
# \ Loading images (1 containers initializing)... View app at
# / Loading images (1 containers initializing)... View app at
# \ Loading images (1 containers initializing)... View app at
# / Loading images (1 containers initializing)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# dal.com/apps/vincenman/main/ap-Box2DdaDcrEH4RLmnhaYwp
# \ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# / Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# Fetching 2 files:  50%|█████     | 1/2 [00:02<00:02,  2.22s/it]
# / Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Fetching 2 files: 100%|██████████| 2/2 [00:19<00:00, 11.08s/it]
# Fetching 2 files: 100%|██████████| 2/2 [00:19<00:00,  9.75s/it]mView app at https://modal.com/apps/vincenm
# \ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# dal.com/apps/vincenman/main/ap-Box2DdaDcrEH4RLmnhaYwp
# / Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Loading weights:   0%|          | 0/164 [00:00<?, ?it/s]
# Loading weights:   1%|          | 2/164 [00:00<00:09, 17.66it/s]View app at https://modal.com/apps/vincenm
# \ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Loading weights:   9%|▊         | 14/164 [00:00<00:02, 73.91it/s]
# Loading weights:  19%|█▉        | 31/164 [00:00<00:01, 112.39it/s]37mView app at https://modal.com/apps/vincenm
# Loading weights:  29%|██▉       | 48/164 [00:00<00:00, 130.75it/s]37mView app at https://modal.com/apps/vincenm
# / Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Loading weights:  38%|███▊      | 62/164 [00:00<00:00, 131.29it/s]
# \ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Loading weights:  46%|████▋     | 76/164 [00:00<00:00, 131.27it/s]
# Loading weights:  57%|█████▋    | 93/164 [00:00<00:00, 139.52it/s]37mView app at https://modal.com/apps/vincenm
# Loading weights:  65%|██████▌   | 107/164 [00:00<00:00, 137.83it/s]7mView app at https://modal.com/apps/vincenm
# / Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Loading weights:  74%|███████▍  | 121/164 [00:00<00:00, 134.97it/s]
# Loading weights:  84%|████████▍ | 138/164 [00:01<00:00, 141.54it/s]7mView app at https://modal.com/apps/vincenm
# Loading weights:  93%|█████████▎| 153/164 [00:01<00:00, 140.77it/s]7mView app at https://modal.com/apps/vincenm
# Loading weights: 100%|██████████| 164/164 [00:01<00:00, 131.66it/s]7mView app at https://modal.com/apps/vincenm
# \ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# https://modal.com/apps/vincenman/main/ap-Box2DdaDcrEH4RLmnhaYwp
# Stopping app - local entrypoint completed.
# [modal-client] 2026-09-19T07:35:07+0800 Timed out waiting for final app logs.
# ✓ App completed. View run at
# https://modal.com/apps/vincenman/main/ap-Box2DdaDcrEH4RLmnhaYwp
# '<bos>Never gonna give you up, never gonna let you down, never'

# %%
from pricer_ephemeral import app, price

# %%
with modal.enable_output():
    with app.run():
        result=price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
result
# Out:
# ✓ Initialized. View run at
# https://modal.com/apps/vincenman/main/ap-IkEJOvIEIssx4CcyUTJmgJ
# - Initializing...
# / Creating objects...objects...
# └── - Creating mount
#     d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\pric
# | Creating objects...
# └── | Creating mount
#     d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\pric
# - Creating objects...
# └── - Creating mount
#     d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\pric
# | Creating objects...
# └── | Creating mount
#     d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\pric
# - Creating objects...
# └── - Creating mount
#     d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\pric
# | Creating objects...
# └── | Creating mount
#     d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\pric
# - Creating objects...
# └── - Creating mount
#     d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\pric
# | Creating objects...
# └── | Creating mount
#     d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\pric
# - Creating objects...
# ├── 🔨 Created mount
# │   d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\pric
# │   er_ephemeral.py
# | Creating objects...
# ├── 🔨 Created mount
# │   d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\pric
# │   er_ephemeral.py
# / Creating objects...
# ├── 🔨 Created mount
# │   d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\pric
# │   er_ephemeral.py
# └── 🔨 Created function price.
# ✓ Created objects.
# ├── 🔨 Created mount
# │   d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\pric
# │   er_ephemeral.py
# └── 🔨 Created function price.
# - Running... View app at
# | Loading images (1 containers initializing)... View app at
# - Loading images (1 containers initializing)... View app at
# | Loading images (1 containers initializing)... View app at
# - Loading images (1 containers initializing)... View app at
# | Loading images (1 containers initializing)... View app at
# - Loading images (1 containers initializing)... View app at
# | Loading images (1 containers initializing)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# dal.com/apps/vincenman/main/ap-IkEJOvIEIssx4CcyUTJmgJ
# | Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at \ Running (1/1 containers active)... View app at https://modal.com/apps/vincenm
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# - Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# | Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# dal.com/apps/vincenman/main/ap-IkEJOvIEIssx4CcyUTJmgJ
# \ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# Fetching 2 files:  50%|█████     | 1/2 [00:36<00:36, 36.94s/it]
# / Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Fetching 2 files: 100%|██████████| 2/2 [00:37<00:00, 15.68s/it]
# Fetching 2 files: 100%|██████████| 2/2 [00:37<00:00, 18.87s/it]mView app at https://modal.com/apps/vincenm
# \ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# / Running (1/1 containers active)... View app at
# dal.com/apps/vincenman/main/ap-IkEJOvIEIssx4CcyUTJmgJ
# \ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# / Running (1/1 containers active)... View app at
# Loading weights:   0%|          | 0/883 [00:00<?, ?it/s]
# \ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Loading weights:   0%|          | 1/883 [00:00<06:17,  2.34it/s]
# Loading weights:   0%|          | 3/883 [00:00<02:28,  5.94it/s]View app at https://modal.com/apps/vincenm
# / Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Loading weights:   2%|▏         | 18/883 [00:00<00:21, 39.52it/s]
# \ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Loading weights:   5%|▍         | 42/883 [00:00<00:09, 87.77it/s]
# Loading weights:   6%|▋         | 56/883 [00:00<00:08, 101.10it/s]37mView app at https://modal.com/apps/vincenm
# Loading weights:   8%|▊         | 70/883 [00:01<00:07, 107.81it/s]37mView app at https://modal.com/apps/vincenm
# Loading weights:  10%|█         | 91/883 [00:01<00:05, 134.70it/s]37mView app at https://modal.com/apps/vincenm
# / Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Loading weights:  12%|█▏        | 107/883 [00:01<00:05, 137.42it/s]
# Loading weights:  14%|█▍        | 123/883 [00:01<00:05, 132.68it/s]7mView app at https://modal.com/apps/vincenm
# \ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Loading weights:  17%|█▋        | 146/883 [00:01<00:04, 154.92it/s]
# Loading weights:  18%|█▊        | 163/883 [00:01<00:04, 152.39it/s]7mView app at https://modal.com/apps/vincenm
# / Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Loading weights:  21%|██        | 185/883 [00:01<00:04, 161.20it/s]
# Loading weights:  23%|██▎       | 202/883 [00:01<00:04, 152.80it/s]7mView app at https://modal.com/apps/vincenm
# \ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Loading weights:  25%|██▌       | 224/883 [00:01<00:04, 162.96it/s]
# Loading weights:  27%|██▋       | 241/883 [00:02<00:04, 154.60it/s]7mView app at https://modal.com/apps/vincenm
# / Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Loading weights:  30%|██▉       | 263/883 [00:02<00:03, 164.22it/s]
# Loading weights:  32%|███▏      | 280/883 [00:02<00:03, 153.09it/s]7mView app at https://modal.com/apps/vincenm
# \ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Loading weights:  34%|███▍      | 300/883 [00:02<00:03, 165.05it/s]
# Loading weights:  36%|███▌      | 317/883 [00:02<00:03, 146.43it/s]7mView app at https://modal.com/apps/vincenm
# Loading weights:  38%|███▊      | 338/883 [00:02<00:03, 161.50it/s]7mView app at https://modal.com/apps/vincenm
# / Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Loading weights:  40%|████      | 355/883 [00:02<00:03, 152.21it/s]
# Loading weights:  42%|████▏     | 371/883 [00:02<00:03, 150.30it/s]7mView app at https://modal.com/apps/vincenm
# \ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Loading weights:  44%|████▍     | 388/883 [00:03<00:03, 152.38it/s]
# Loading weights:  46%|████▌     | 406/883 [00:03<00:03, 148.48it/s]7mView app at https://modal.com/apps/vincenm
# / Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Loading weights:  48%|████▊     | 422/883 [00:03<00:03, 137.09it/s]
# Loading weights:  50%|█████     | 442/883 [00:03<00:02, 152.81it/s]7mView app at https://modal.com/apps/vincenm
# \ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Loading weights:  57%|█████▋    | 505/883 [00:03<00:01, 279.64it/s]
# Loading weights:  65%|██████▌   | 577/883 [00:03<00:00, 400.54it/s]7mView app at https://modal.com/apps/vincenm
# / Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# Loading weights:  73%|███████▎  | 649/883 [00:03<00:00, 485.70it/s]
# Loading weights:  81%|████████  | 712/883 [00:03<00:00, 526.75it/s]7mView app at https://modal.com/apps/vincenm
# Loading weights:  88%|████████▊ | 779/883 [00:03<00:00, 565.11it/s]7mView app at https://modal.com/apps/vincenm
# Loading weights:  96%|█████████▌| 849/883 [00:04<00:00, 594.71it/s]7mView app at https://modal.com/apps/vincenm
# Loading weights: 100%|██████████| 883/883 [00:04<00:00, 218.19it/s]7mView app at https://modal.com/apps/vincenm
# \ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at  View app at https://modal.com/apps/vincenm
# /usr/local/lib/python3.12/site-packages/peft/peft_model.py:642: UserWarning: Found missing adapter keys while loading the checkpoint: ['base_model.model.model.vision_tower.encoder.layers.0.self_attn.k_proj.lora_A.default.weight', 'base_model.model.model.vision_tower.encoder.layers.0.self_attn.k_proj.lora_B.default.weight', 'base_model.model.model.vision_tower.encoder.layers.0.self_attn.v_proj.lora_A.default.weight', 'base_model.model.model.vision_tower.encoder.layers.0.self_attn.v_proj.lora_B.default.weight', 'base_model.model.model.vision_tower.encoder.layers.0.self_attn.q_proj.lora_A.default.weight', 'base_model.model.model.vision_tower.encoder.layers.0.self_attn.q_proj.lora_B.default.weight', 'base_model.model.model.vision_tower.encoder.layers.1.self_attn.k_proj.lora_A.default.weight', 'base_model.model.model.vision_tower.encoder.layers.1.self_attn.k_proj.lora_B.default.weight', 'base_model.model.model.vision_tower.encoder.layers.1.self_attn.v_proj.lora_A.default.weight', 'base_model.model.model.vision_tower.encoder.layers.1.self_attn.v_proj.lora_B.default.weight', 'base_model.model.model.vision_tower.encoder.layers.1.self_attn.q_proj.lora_A.default.weight', 'base_model.model.model.vision_tower.encoder.layers.1.self_attn.q_proj.lora_B.default.weight', 'base_model.model.model.vision_tower.encoder.layers.2.self_attn.k_proj.lora_A.default.weight', 'base_model.model.model.vision_tower.encoder.layers.2.self_attn.k_proj.lora_B.default.weight', 'base_model.model.model.vision_tower.encoder.layers.2.self_attn.v_proj.lora_A.default.weight', 'base_model.model.model.vision_tower.encoder.layers.2.self_attn.v_proj.lora_B.default.weight', 'base_model.model.model.vision_tower.encoder.layers.2.self_attn.q_proj.lora_A.default.weight', 'base_model.model.model.vision_tower.encoder.layers.2.self_attn.q_proj.lora_B.default.weight', 'base_model.model.model.vision_tower.encoder.layers.3.self_attn.k_proj.lora_A.default.weight', 'base_model.model.model.vision_tower.encoder.layers.3.self_attn.k_proj.lora_B.default.weight', 'base_model.model.model.vision_tower.encoder.layers.3.self_attn.v_proj.lora_A.default.weight', 'base_model.model.model.vision_tower.encoder.layers.3.self_attn.v_proj.lora_B.default.weight', 'base_model.model.model.vision_tower.encoder.layers.3.self_attn.q_proj.lora_A.default.weight', 'base_model.model.model.vision_tower.encoder.layers.3.self_attn.q_proj.lora_B.default.weight', 'base_model.model.model.vision_tower.encoder.layers.4.self_attn.k_proj.lora_A.default.weight', 'base_model.model.model.vision_tower.encoder.layers.4.self_attn.k_proj.lora_B.default.weight', 'base_model.model.model.vision_tower.encoder.layers.4.self_attn.v_proj.lora_A.default.weight', 'base_model.model.model.vision_tower.encoder.layers.4.self_attn.v_proj.lora_B.default.weight', 'base_model.model.model.vision_tower.encoder.layers.4.self_attn.q_proj.lora_A.default.weight', 'base_model.model.model.vision_tower.encoder.layers.4.self_attn.q_proj.lora_B.default.weight', 'base_model.model.model.vision_tower.encoder.layers.5.self_attn.k_proj.lora_A.default.weight', 'base_model.model.model.vision_tower.encoder.layers.5.self_attn.k_proj.lora_B.default.weight', 'base_model.model.model.vision_tower.encoder.layers.5.self_attn.v_proj.lora_A.default.weight', 'base_model.model.model.vision_tower.encoder.layers.5.self_attn.v_proj.lora_B.default.weight', 'base_model.model.model.vision_tower.encoder.layers.5.self_attn.q_proj.lora_A.default.weight', 'base_model.model.model.vision_tower.encoder.layers.5.self_attn.q_proj.lora_B.default.weight', 'base_model.model.model.vision_tower.encoder.layers.6.self_attn.k_proj.lora_A.default.weight', 'base_model.model.model.vision_tower.encoder.layers.6.self_attn.k_proj.lora_B.default.weight', 'base_model.model.model.vision_tower.encoder.layers.6.self_attn.v_proj.lora_A.default.weight', 'base_model.model.model.vision_tower.encoder.layers.6.self_attn.v_proj.lora_B.default.weight', 'base_model.model.model.vision_tower.encoder.layers.6.self_attn.q ...
#   warnings.warn(warn_message)
# \ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/vincenm
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# \ Running (1/1 containers active)... View app at
# / Running (1/1 containers active)... View app at
# https://modal.com/apps/vincenman/main/ap-IkEJOvIEIssx4CcyUTJmgJ
# Stopping app - local entrypoint completed.
# Runner terminated.
# ✓ App completed. View run at
# https://modal.com/apps/vincenman/main/ap-IkEJOvIEIssx4CcyUTJmgJ
# 149.9

# %%
preprocessor = Preprocessor()
text = preprocessor.preprocess("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(text)
# Out:
# ### System:
# Title: Crystal Clear USB Microphone
# Category: Electronics
# Brand: HyperX
# Description: A high-quality condenser microphone for professional-grade audio recording and streaming.
# Details: Equipped with USB-C connectivity for seamless plug-and-play setup and crystal clear audio quality.

# %%
#preprocessor = Preprocessor(model_name="groq/openai/gpt-oss-20b")
preprocessor = Preprocessor(model_name="openrouter/openai/gpt-oss-20b")
text = preprocessor.preprocess("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(text)
# Out:
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:190, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     189 try:
# --> 190     response = sync_httpx_client.post(
#     191         url=api_base,
#     192         headers=headers,
#     193         data=(
#     194             signed_json_body
#     195             if signed_json_body is not None
#     196             else json.dumps(data)
#     197         ),
#     198         timeout=timeout,
#     199         stream=stream,
#     200         logging_obj=logging_obj,
#     201     )
#     202 except httpx.HTTPStatusError as e:
#
# File d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\.venv\Lib\site-packages\litellm\llms\custom_httpx\http_handler.py:898, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     897     setattr(e, "status_code", e.response.status_code)
# --> 898     raise e
#     899 except Exception as e:
#
# File d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\.venv\Lib\site-packages\litellm\llms\custom_httpx\http_handler.py:880, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     879 response = self.client.send(req, stream=stream)
# --> 880 response.raise_for_status()
#     881 return response
#
# File d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\.venv\Lib\site-packages\httpx\_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '403 Forbidden' for url 'https://api.groq.com/openai/v1/chat/completions'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403
#
# During handling of the above exception, another exception occurred:
#
# OpenAIError                               Traceback (most recent call last)
# File d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\.venv\Lib\site-packages\litellm\main.py:1940, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    1938             optional_params[k] = v
# -> 1940     response = base_llm_http_handler.completion(
#    1941         model=model,
#    1942         stream=stream,
#    1943         messages=messages,
#    1944         acompletion=acompletion,
#    1945         api_base=api_base,
#    1946         model_response=model_response,
#    1947         optional_params=optional_params,
#    1948         litellm_params=litellm_params,
#    1949         shared_session=shared_session,
#    1950         custom_llm_provider=custom_llm_provider,
#    1951         timeout=timeout,
#    1952         headers=headers,
#    1953         encoding=encoding,
#    1954         api_key=api_key,
#    1955         logging_obj=logging,  # model call logging done inside the class as we make need to modify I/O to fit aleph alpha's requirements
#    1956         client=client,
#    1957     )
#    1958 elif custom_llm_provider == "aiohttp_openai":
#    1959     # NEW aiohttp provider for 10-100x higher RPS
#
# File d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:493, in BaseLLMHTTPHandler.completion(self, model, messages, api_base, custom_llm_provider, model_response, encoding, logging_obj, optional_params, timeout, litellm_params, acompletion, stream, fake_stream, api_key, headers, client, provider_config, shared_session)
#     491     sync_httpx_client = client
# --> 493 response = self._make_common_sync_call(
#     494     sync_httpx_client=sync_httpx_client,
#     495     provider_config=provider_config,
#     496     api_base=api_base,
#     497     headers=headers,
#     498     data=data,
#     499     signed_json_body=signed_json_body,
#     500     timeout=timeout,
#     501     litellm_params=litellm_params,
#     502     logging_obj=logging_obj,
#     503 )
#     504 return provider_config.transform_response(
#     505     model=model,
#     506     raw_response=response,
#    (...)    515     json_mode=json_mode,
#     516 )
#
# File d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:215, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     214     else:
# --> 215         raise self._handle_error(e=e, provider_config=provider_config)
#     216 except Exception as e:
#
# File d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:3517, in BaseLLMHTTPHandler._handle_error(self, e, provider_config)
#    3511     raise BaseLLMException(
#    3512         status_code=status_code,
#    3513         message=error_text,
#    3514         headers=error_headers,
#    3515     )
# -> 3517 raise provider_config.get_error_class(
#    3518     error_message=error_text,
#    3519     status_code=status_code,
#    3520     headers=error_headers,
#    3521 )
#
# OpenAIError: {"error":{"message":"Forbidden"}}
#
# During handling of the above exception, another exception occurred:
#
# APIError                                  Traceback (most recent call last)
# Cell In[16], line 2
#       1 preprocessor = Preprocessor(model_name="groq/openai/gpt-oss-20b")
# ----> 2 text = preprocessor.preprocess("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
#       3 print(text)
#
# File d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\week8\agents\preprocessor.py:39, in Preprocessor.preprocess(self, text)
#      37 def preprocess(self, text: str) -> str:
#      38     messages = self.messages_for(text)
# ---> 39     response = completion(
#      40         messages=messages,
#      41         model=self.model_name,
#      42         reasoning_effort=self.reasoning_effort,
#      43         api_base=self.base_url,
#      44     )
#      45     self.total_input_tokens += response.usage.prompt_tokens
#      46     self.total_output_tokens += response.usage.completion_tokens
#
# File d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\.venv\Lib\site-packages\litellm\utils.py:1376, in client.<locals>.wrapper(*args, **kwargs)
#    1372 if logging_obj:
#    1373     logging_obj.failure_handler(
#    1374         e, traceback_exception, start_time, end_time
#    1375     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1376 raise e
#
# File d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\.venv\Lib\site-packages\litellm\utils.py:1245, in client.<locals>.wrapper(*args, **kwargs)
#    1243         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1244 # MODEL CALL
# -> 1245 result = original_function(*args, **kwargs)
#    1246 end_time = datetime.datetime.now()
#    1247 if _is_streaming_request(
#    1248     kwargs=kwargs,
#    1249     call_type=call_type,
#    1250 ):
#
# File d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\.venv\Lib\site-packages\litellm\main.py:3767, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    3764     return response
#    3765 except Exception as e:
#    3766     ## Map to OpenAI Exception
# -> 3767     raise exception_type(
#    3768         model=model,
#    3769         custom_llm_provider=custom_llm_provider,
#    3770         original_exception=e,
#    3771         completion_kwargs=args,
#    3772         extra_kwargs=kwargs,
#    3773     )
#
# File d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2274, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2272 if exception_mapping_worked:
#    2273     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2274     raise e
#    2275 else:
#    2276     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File d:\Training\llm_engineering-main(Ed_donner)\llm_engineering-main\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:530, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     528     else:
#     529         exception_mapping_worked = True
# --> 530         raise APIError(
#     531             status_code=original_exception.status_code,
#     532             message=f"APIError: {exception_provider} - {message}",
#     533             llm_provider=custom_llm_provider,
#     534             model=model,
#     535             request=getattr(original_exception, "request", None),
#     536             litellm_debug_info=extra_information,
#     537         )
#     538 else:
#     539     # if no status code then it is an APIConnectionError: https://github.com/openai/openai-python#handling-errors
#     540     # exception_mapping_worked = True
#     541     raise APIConnectionError(
#     542         message=f"APIConnectionError: {exception_provider} - {message}",
#     543         llm_provider=custom_llm_provider,
#    (...)    548         ),
#     549     )
#
# APIError: litellm.APIError: APIError: GroqException - {"error":{"message":"Forbidden"}}

# %% [markdown]
# ### Add this to your .env if you want the Preprocessor to use a different model by default:
#
# `PRICER_PREPROCESSOR_MODEL=groq/openai/gpt-oss-20b`

# %%
with modal.enable_output():
    with app.run():
        result = price.remote(text)
print(result)

# %%
print(text)

# %% [markdown]
# ## Transitioning From Ephemeral Apps to Deployed Apps
#
# From a command line, `uv run modal deploy xxx` will deploy your code as a Deployed App
#
# This is how you could package your AI service behind an API to be used in a Production System.
#
# You can also build REST endpoints easily, although we won't cover that as we'll be calling direct from Python.
#
# ## Important note about secrets
#
# In both the files `pricer_service.py` and `pricer_service2.py` you will find code like this near the top:
# `secrets = [modal.Secret.from_name("hf-secret")]`
# You may need to change from `hf-secret` to `huggingface-secret` depending on how the Secret is configured in modal.
# To check, visit this page and look in the first column:
# https://modal.com/secrets/
#
# ## Important note for Windows people:
#
# On the next line, I call `uv run modal deploy` from within Jupyter lab; I've heard that on some versions of Windows this gives a strange unicode error because modal prints emojis to the output which can't be displayed. If that happens to you, open a Terminal and run `uv run modal deploy..`

# %%
# You can also run "uv run modal deploy -m pricer_service" in the Terminal

# !uv run modal deploy -m pricer_service

# %%
pricer = modal.Function.from_name("pricer-service", "price")

# %% [markdown]
# Watch it happening:
#
# https://modal.com

# %%
# This can take a while! We'll use faster approaches shortly

pricer.remote(text)

# %%
# You can also run "modal deploy -m pricer_service2" at the command line in an activated environment

# !modal deploy -m pricer_service2

# %%
Pricer = modal.Cls.from_name("pricer-service", "Pricer")
pricer = Pricer()
reply = pricer.price.remote(text)
print(reply)

# %%
reply = pricer.price.remote(text)
print(reply)

# %% [markdown]
# # Optional: Keeping Modal warm
#
# ## A way to improve the speed of the Modal pricer service
#
# The first time you run this modal class, it might take as much as 10 minutes to build.
# Subsequently it should be much faster.. 30 seconds if it needs to wake up, otherwise 2 seconds.
# If you want it to always be 2 seconds, you can keep the container from going to sleep by editing this constant in pricer_service2.py:
#
# `MIN_CONTAINERS = 0`
#
#
#
# Make it 1 to keep a container alive.
# But please note: this will eat up credits! Only do this if you are comfortable to have a process running continually.
#
# Alternatively, you can run this code and it will stay warm for 20 mins rather than 2 mins.
#
# ### Code to keep warm for 20 mins before cooling down:
#
# ```python
# import modal
# Pricer = modal.Cls.from_name("pricer-service", "Pricer")
# pricer = Pricer()
# pricer.update_autoscaler(scaledown_window=1200)
# ```
#
# ### Code to revert to keeping warm for only 2 mins
#
# ```python
# import modal
# Pricer = modal.Cls.from_name("pricer-service", "Pricer")
# pricer = Pricer()
# pricer.update_autoscaler(scaledown_window=120)
# ```

# %% [markdown]
# ## And now introducing our Agent class
#
# By default this will preprocess using Llama3.2
#
# If you'd prefer to use Groq, then add this env variable like:
#
# ```
# PRICER_PREPROCESSOR_MODEL=groq/openai/gpt-oss-20b
# ```

# %%
import logging
root = logging.getLogger()
root.setLevel(logging.INFO)

# %%
from agents.specialist_agent import SpecialistAgent

# %%
agent = SpecialistAgent()

# %%
agent.price("iPhone 10")
